# %%
# %matplotlib inline
import numpy as np
import pandas as pd

# %% [markdown]
# head() is a handy way to visualize what you've loaded. You can pass it an integer to see some specific number of rows at the beginning of your DataFrame.

# %%
df = pd.read_csv("FuelEfficiency.csv")
df.head(12)
# Out:
#                Mfr Name           Carline  Eng Displ  Cylinders Transmission  \
# 0          aston martin        Vantage V8        4.0          8     Auto(S8)
# 1   Volkswagen Group of            Chiron        8.0         16  Auto(AM-S7)
# 2        General Motors          CORVETTE        6.2          8     Auto(S8)
# 3        General Motors          CORVETTE        6.2          8     Auto(S8)
# 4        General Motors          CORVETTE        6.2          8     Auto(S8)
# 5        General Motors          CORVETTE        6.2          8   Manual(M7)
# 6        General Motors          CORVETTE        6.2          8   Manual(M7)
# 7        General Motors          CORVETTE        6.2          8   Manual(M7)
# 8               Ferrari           488 gtb        3.9          8    Auto(AM7)
# 9               Ferrari           488 gtb        3.9          8    Auto(AM7)
# 10              Ferrari         488 Pista        3.9          8    Auto(AM7)
# ...

# %% [markdown]
# You can also view the end of your data with tail():

# %%
df.tail()
# Out:
#     Mfr Name                 Carline  Eng Displ  Cylinders Transmission  \
# 713   Toyota             4RUNNER 4WD        4.0          6     Auto(S5)
# 714   Toyota  LAND CRUISER WAGON 4WD        5.7          8     Auto(S8)
# 715   Toyota             SEQUOIA 4WD        5.7          8     Auto(S6)
# 716    Volvo                XC90 AWD        2.0          4     Auto(S8)
# 717    Volvo                XC90 AWD        2.0          4     Auto(S8)
#
#      CityMPG  HwyMPG  CombMPG  # Gears
# 713       17      20       18        5
# 714       13      18       15        8
# 715       13      17       14        6
# 716       19      26       22        8
# 717       20      27       23        8
#     Mfr Name                 Carline  Eng Displ  Cylinders Transmission  \
# 713   Toyota             4RUNNER 4WD        4.0          6     Auto(S5)
# 714   Toyota  LAND CRUISER WAGON 4WD        5.7          8     Auto(S8)
# 715   Toyota             SEQUOIA 4WD        5.7          8     Auto(S6)
# ...

# %% [markdown]
# If your DataFrame has named columns (in our case, extracted automatically from the first row of a .csv file,) you can get an array of them back.

# %%
df.columns
# Out:
# Index(['Mfr Name', 'Carline', 'Eng Displ', 'Cylinders', 'Transmission',
#        'CityMPG', 'HwyMPG', 'CombMPG', '# Gears'],
#       dtype='object')
# Index(['Mfr Name', 'Carline', 'Eng Displ', 'Cylinders', 'Transmission',
#        'CityMPG', 'HwyMPG', 'CombMPG', '# Gears'],
#       dtype='object')

# %% [markdown]
# We often talk about the "shape" of your DataFrame. This is just its dimensions. This particular CSV file has 13 rows with 7 columns per row:

# %%
df.shape
# Out:
# (718, 9)
# (718, 9)

# %% [markdown]
# Extracting a single column from your DataFrame looks like this - this gives you back a "Series" in Pandas:

# %%
df["Transmission"]
# Out:
# 0         Auto(S8)
# 1      Auto(AM-S7)
# 2         Auto(S8)
# 3         Auto(S8)
# 4         Auto(S8)
# 5       Manual(M7)
# 6       Manual(M7)
# 7       Manual(M7)
# 8        Auto(AM7)
# 9        Auto(AM7)
# 10       Auto(AM7)
# 11       Auto(AM7)
# 12       Auto(AM7)
# 13       Auto(AM7)
# 14       Auto(AM7)
# 15        Auto(A6)
# 16      Manual(M6)
# 17        Auto(S8)
# 18        Auto(S8)
# 19      Manual(M6)
# 20        Auto(S8)
# 21        Auto(S8)
# 22      Manual(M6)
# 23        Auto(S8)
# 24        Auto(S8)
# 25        Auto(S8)
# 26      Manual(M6)
# 27        Auto(S8)
# 28      Manual(M6)
# 29     Auto(AM-S7)
#           ...
# 688      Auto(A10)
# 689       Auto(S7)
# 690       Auto(A8)
# 691       Auto(A8)
# 692       Auto(S8)
# 693       Auto(S8)
# 694       Auto(S8)
# 695       Auto(S8)
# 696       Auto(S8)
# 697       Auto(S8)
# 698       Auto(S8)
# 699       Auto(S8)
# 700       Auto(S8)
# 701       Auto(S8)
# 702       Auto(S8)
# 703       Auto(S6)
# ...

# %%
df["Carline"]
# Out:
# 0                       Vantage V8
# 1                           Chiron
# 2                         CORVETTE
# 3                         CORVETTE
# 4                         CORVETTE
# 5                         CORVETTE
# 6                         CORVETTE
# 7                         CORVETTE
# 8                          488 gtb
# 9                          488 gtb
# 10                       488 Pista
# 11                488 Pista Spider
# 12                      488 Spider
# 13                      488 Spider
# 14                   812 Superfast
# 15                      124 Spider
# 16                      124 Spider
# 17              F-TYPE Convertible
# 18              F-TYPE Convertible
# 19       F-TYPE Convertible Manual
# 20                    F-TYPE Coupe
# 21                    F-TYPE Coupe
# 22             F-TYPE Coupe Manual
# 23        F-TYPE S AWD Convertible
# 24              F-TYPE S AWD Coupe
# 25            F-TYPE S Convertible
# 26     F-TYPE S Convertible Manual
# ...

# %% [markdown]
# To extract more than one column, you pass in an array of column names instead of a single one:

# %%
df[['Mfr Name',"Eng Displ"]]
# Out:
#                 Mfr Name  Eng Displ
# 0           aston martin        4.0
# 1    Volkswagen Group of        8.0
# 2         General Motors        6.2
# 3         General Motors        6.2
# 4         General Motors        6.2
# 5         General Motors        6.2
# 6         General Motors        6.2
# 7         General Motors        6.2
# 8                Ferrari        3.9
# 9                Ferrari        3.9
# 10               Ferrari        3.9
# 11               Ferrari        3.9
# 12               Ferrari        3.9
# 13               Ferrari        3.9
# 14               Ferrari        6.5
# 15            FCA US LLC        1.4
# 16            FCA US LLC        1.4
# 17   Jaguar Land Rover L        2.0
# 18   Jaguar Land Rover L        3.0
# 19   Jaguar Land Rover L        3.0
# 20   Jaguar Land Rover L        2.0
# 21   Jaguar Land Rover L        3.0
# 22   Jaguar Land Rover L        3.0
# 23   Jaguar Land Rover L        3.0
# 24   Jaguar Land Rover L        3.0
# ...

# %% [markdown]
# Breaking down the number of unique values in a given column into a Series using value_counts() - this is a good way to understand the distribution of your data:

# %%
degree_counts = df['Mfr Name'].value_counts()
degree_counts
# Out:
# General Motors          137
# BMW                     108
# FCA US LLC               60
# Jaguar Land Rover L      55
# Porsche                  52
# Toyota                   44
# Hyundai                  42
# Honda                    33
# Nissan                   29
# Ford Motor Company       28
# Kia                      27
# Subaru                   22
# Volvo                    19
# Mercedes-Benz            18
# Ferrari                  10
# Maserati                  8
# Volkswagen Group of       8
# Mitsubishi Motors Co      7
# MAZDA                     4
# Rolls-Royce               4
# aston martin              3
# Name: Mfr Name, dtype: int64
# General Motors          137
# BMW                     108
# FCA US LLC               60
# Jaguar Land Rover L      55
# Porsche                  52
# Toyota                   44
# Hyundai                  42
# Honda                    33
# Nissan                   29
# Ford Motor Company       28
# Kia                      27
# ...

# %% [markdown]
# Pandas even makes it easy to plot a Series or DataFrame by just calling plot():

# %%
degree_counts.plot(kind='box')

# %%
degree_counts.plot(kind='bar')

# %%
degree_counts.plot(kind='pie')
